# %% [markdown]
# # LAB | Error Handling in Python
#
# ## Overview
# This exercise notebook will help you practice error handling in Python using exceptions. You will write programs that handle various types of exceptions to ensure your code runs smoothly and handles errors gracefully.

# %% [markdown]
# ### Exercise 1: Handle ZeroDivisionError
# Write a Python program to handle a `ZeroDivisionError` exception when dividing a number by zero.

# %%
# Your code here
var1 = 2
var2 = 0
try:
    resutl = var1 / var2
except ZeroDivisionError:
    print("Can not divide by zero")
# Out:
# Can not divide by zero

# %% [markdown]
# ### Exercise 2: Raise ValueError for Invalid Input
# Write a Python program that prompts the user to input an integer and raises a `ValueError` exception if the input is not a valid integer.

# %%
# Your code here
input_user = input("Please enter a number")
try:
    input_user = int(input_user)
except ValueError:
    print("Please enter a valid integer")
    # raise ValueError("Please enter a integer value")
# Out:
# Please enter a valid integer

# %% [markdown]
# ### Exercise 3: Handle FileNotFoundError
# Write a Python program that opens a file and handles a `FileNotFoundError` exception if the file does not exist.

# %%
# Your code here

try:
    file = open("path.txt", "r")
except FileNotFoundError:
    print("File was not found")
# Out:
# File was not found

# %% [markdown]
# ### Exercise 4: Raise TypeError for Non-Numerical Input
# Write a Python program that prompts the user to input two numbers and raises a `TypeError` exception if the inputs are not numerical.

# %%
# Your code here
user_input_1 = input("Please enter a integer number")
user_input_2 = input("Please enter another integer number")

try:
    user_input_1 = int(user_input_1)
    user_input_2 = int(user_input_2)
except ValueError:
    print("Please enter only numbers")
    raise TypeError("Please enter only numbers")
# Out:
# Please enter only numbers
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 7
#       6     user_input_1 = int(user_input_1)
# ----> 7     user_input_2 = int(user_input_2)
#       8 except ValueError:
#
# ValueError: invalid literal for int() with base 10: 'ds'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 10
#       8 except ValueError:
#       9     print("Please enter only numbers")
# ---> 10     raise TypeError("Please enter only numbers")
#
# TypeError: Please enter only numbers

# %% [markdown]
# ### Exercise 5: Handle PermissionError
# Write a Python program that opens a file and handles a `PermissionError` exception if there is a permission issue.

# %%
# Your code here
try:
    file = open("test.txt", "r")
    file.close()
except PermissionError:
    print("PermissionError: File can not be opened")

# %% [markdown]
# ### Exercise 6: Handle IndexError in List Operations
# Write a Python program that executes an operation on a list and handles an `IndexError` exception if the index is out of range.

# %%
# Your code here

list = [1, 2, 3, 4]


for i in range(0,10):
    try:
        print(list[i])
    except IndexError:
        print(f"IndexError: Index {i} is out of range")
# Out:
# 1
# 2
# 3
# 4
# IndexError: Index 4 is out of range
# IndexError: Index 5 is out of range
# IndexError: Index 6 is out of range
# IndexError: Index 7 is out of range
# IndexError: Index 8 is out of range
# IndexError: Index 9 is out of range

# %% [markdown]
# ### Exercise 7: Handle KeyboardInterrupt Exception
# Write a Python program that prompts the user to input a number and handles a `KeyboardInterrupt` exception if the user cancels the input.

# %%
# Your code here

try:
    user_input = input("Please enter some text")
except KeyboardInterrupt:
    print("No input was given")

# %% [markdown]
# ### Exercise 8: Handle ArithmeticError
# Write a Python program that executes division and handles an `ArithmeticError` exception if there is an arithmetic error.

# %%
# Your code here
import math
try:
    result = math.exp(1000)
except ArithmeticError:
    print("ArithmeticError: overflow")
# Out:
# ArithmeticError: overflow

# %% [markdown]
# ### Exercise 9: Handle UnicodeDecodeError
# Write a Python program that opens a file and handles a `UnicodeDecodeError` exception if there is an encoding issue.

# %%
# Your code here
try:
    file = open("test.txt", "r")
except UnicodeDecodeError:
    print("UnicodeDecodeError: There is an encoding issue")

# %% [markdown]
# ### Exercise 10: Handle AttributeError
# Write a Python program that executes an operation on an object and handles an `AttributeError` exception if the attribute does not exist.

# %%
# Your code here
class Person:
    def __init__(self, name):
        self.name = name


person = Person("Alice")
try:
    value = getattr(person, "name")
    value = getattr(person, "age")
except AttributeError:
    print("object doesn't have the given attribute")
# Out:
# object doesn't have the given attribute

# %% [markdown]
# ## Bonus Exercises
#
# ### Bonus Exercise 1: Handle Multiple Exceptions
# Write a Python program that demonstrates handling multiple exceptions in one block.

# %%
# Your code here
import math
try:
    # result = math.exp(1000)
    5/0
except (ZeroDivisionError, OverflowError):
    print("ArithmeticError: overflow or division by zero")
# Out:
# ArithmeticError: overflow or division by zero

# %% [markdown]
# ### Bonus Exercise 2: Create Custom Exception
# Create a custom exception class and raise it in your code when certain conditions are met.

# %%
# Your code here
class myException(Exception):
    pass


for i in range(1,1000):
    if i >= 500:
        raise myException("Too many iterations")
# Out:
# ---------------------------------------------------------------------------
# myException                               Traceback (most recent call last)
# Cell In[59], line 8
#       6 for i in range(1,1000):
#       7     if i >= 500:
# ----> 8         raise myException("Too many iterations")
#
# myException: Too many iterations

# %% [markdown]
# ### Bonus Exercise 3: Validate User Input with Exception Handling
# Write a program that repeatedly prompts the user for valid input until they provide it, using exception handling to manage invalid inputs.

# %%
# Your code here
while True:
    input_user = input("Please enter a integer")
    try:
        input_user = int(input_user)
        break
    except ValueError:
        print("Please enter an integer and no float, string etc.")
# Out:
# Please enter an integer and no float, string etc.
# Please enter an integer and no float, string etc.
# Please enter an integer and no float, string etc.

# %% [markdown]
# ### Bonus Exercise 4: Log Errors to File
# Modify your error handling to log errors to a text file instead of printing them to the console.

# %%
# Your code here
# Your code here
while True:
    input_user = input("Please enter a integer")
    try:
        input_user = int(input_user)
        break
    except ValueError:
        with open("error_logs.txt", "a") as file:
            file.write(f"ValueError: User entered invalid Data. {input_user}\n")
        
    except KeyboardInterrupt:
        with open("error_logs.txt", "a") as file:
            file.write(f"KeyboardInterrupt: User exited program manually\n")

# %% [markdown]
# ### Bonus Exercise 5: Retry Logic on Exception
# Implement retry logic for operations that could fail, allowing users to try again after encountering an error.

# %%
# Your code here
retry_count = 5

for retry in range(retry_count):
    input_user = input("Please enter a integer")
    try:
        input_user = int(input_user)
        break
    except ValueError:
        print(f"Please enter only whole numbers. try {retry + 1} of {retry_count}")
# Out:
# Please enter only whole numbers. try 1 of 5
# Please enter only whole numbers. try 2 of 5
# Please enter only whole numbers. try 3 of 5
# Please enter only whole numbers. try 4 of 5
# Please enter only whole numbers. try 5 of 5
