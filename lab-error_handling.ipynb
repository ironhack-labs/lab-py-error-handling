# %% [markdown]
# # LAB | Error Handling in Python
#
# ## Overview
# This exercise notebook will help you practice error handling in Python using exceptions. You will write programs that handle various types of exceptions to ensure your code runs smoothly and handles errors gracefully.

# %% [markdown]
# ### Exercise 1: Handle ZeroDivisionError
# Write a Python program to handle a `ZeroDivisionError` exception when dividing a number by zero.

# %%
try:
    x = int(input("Enter a number: "))
    result = 10 / x
    print("Result:", result)
except ZeroDivisionError:
    print("Error: You cannot divide by zero.")
# Out:
# Result: 0.8333333333333334

# %% [markdown]
# ### Exercise 2: Raise ValueError for Invalid Input
# Write a Python program that prompts the user to input an integer and raises a `ValueError` exception if the input is not a valid integer.

# %%
try:
    num = input("Enter an integer: ")
    if not num.isdigit():
        raise ValueError("Invalid input: not an integer.")
    print("You entered:", int(num))
except ValueError as ve:
    print("Error:", ve)
# Out:
# You entered: 30

# %% [markdown]
# ### Exercise 3: Handle FileNotFoundError
# Write a Python program that opens a file and handles a `FileNotFoundError` exception if the file does not exist.

# %%
try:
    num = input("Enter an integer: ")
    if not num.isdigit():
        raise ValueError("Invalid input: not an integer.")
    print("You entered:", int(num))
except ValueError as ve:
    print("Error:", ve)
# Out:
# You entered: 2

# %% [markdown]
# ### Exercise 4: Raise TypeError for Non-Numerical Input
# Write a Python program that prompts the user to input two numbers and raises a `TypeError` exception if the inputs are not numerical.

# %%
try:
    x = input("Enter first number: ")
    y = input("Enter second number: ")
    if not (x.isdigit() and y.isdigit()):
        raise TypeError("Both inputs must be numbers.")
    print("Sum:", int(x) + int(y))
except TypeError as te:
    print("Error:", te)
# Out:
# Sum: 5

# %% [markdown]
# ### Exercise 5: Handle PermissionError
# Write a Python program that opens a file and handles a `PermissionError` exception if there is a permission issue.

# %%
try:
    with open("/root/protected.txt", "r") as f:  # Use an actual protected file if testing
        print(f.read())
except PermissionError:
    print("Error: You don't have permission to read this file.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 try:
# ----> 2     with open("/root/protected.txt", "r") as f:  # Use an actual protected file if testing
#       3         print(f.read())
#       4 except PermissionError:
#
# File /opt/anaconda3/envs/ironhack/lib/python3.10/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/root/protected.txt'

# %% [markdown]
# ### Exercise 6: Handle IndexError in List Operations
# Write a Python program that executes an operation on a list and handles an `IndexError` exception if the index is out of range.

# %%
my_list = [1, 2, 3]

try:
    print(my_list[5])  
except IndexError:
    print("Error: Index is out of range.")
# Out:
# Error: Index is out of range.

# %% [markdown]
# ### Exercise 7: Handle KeyboardInterrupt Exception
# Write a Python program that prompts the user to input a number and handles a `KeyboardInterrupt` exception if the user cancels the input.

# %%
try:
    input("Press Ctrl+C to interrupt: ")
except KeyboardInterrupt:
    print("\nKeyboardInterrupt caught: You interrupted the input.")

# %% [markdown]
# ### Exercise 8: Handle ArithmeticError
# Write a Python program that executes division and handles an `ArithmeticError` exception if there is an arithmetic error.

# %%
try:
    x = 10
    y = 0
    result = x / y  # This triggers ZeroDivisionError, a subclass of ArithmeticError
except ArithmeticError as ae:
    print("Arithmetic error occurred:", ae)
# Out:
# Arithmetic error occurred: division by zero

# %% [markdown]
# ### Exercise 9: Handle UnicodeDecodeError
# Write a Python program that opens a file and handles a `UnicodeDecodeError` exception if there is an encoding issue.

# %%
try:
    with open("somefile.txt", encoding="ascii") as f:
        print(f.read())
except UnicodeDecodeError:
    print("Error: Unable to decode file due to encoding issue.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 2
#       1 try:
# ----> 2     with open("somefile.txt", encoding="ascii") as f:
#       3         print(f.read())
#       4 except UnicodeDecodeError:
#
# File /opt/anaconda3/envs/ironhack/lib/python3.10/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'somefile.txt'

# %% [markdown]
# ### Exercise 10: Handle AttributeError
# Write a Python program that executes an operation on an object and handles an `AttributeError` exception if the attribute does not exist.

# %%
try:
    num = 42
    num.append(3)  # int object has no append()
except AttributeError:
    print("Error: Attribute not found on the object.")
# Out:
# Error: Attribute not found on the object.

# %% [markdown]
# ## Bonus Exercises
#
# ### Bonus Exercise 1: Handle Multiple Exceptions
# Write a Python program that demonstrates handling multiple exceptions in one block.

# %%
try:
    num = int(input("Enter a number: "))
    result = 10 / num
except ValueError:
    print("Error: You must enter a valid number.")
except ZeroDivisionError:
    print("Error: Cannot divide by zero.")
# Out:
# Error: You must enter a valid number.

# %% [markdown]
# ### Bonus Exercise 2: Create Custom Exception
# Create a custom exception class and raise it in your code when certain conditions are met.

# %%
class TooSmallError(Exception):
    pass

try:
    value = int(input("Enter a number greater than 10: "))
    if value <= 10:
        raise TooSmallError("Number is too small!")
    print("Thanks, input accepted.")
except TooSmallError as e:
    print("Custom Exception:", e)
# Out:
# Custom Exception: Number is too small!

# %% [markdown]
# ### Bonus Exercise 3: Validate User Input with Exception Handling
# Write a program that repeatedly prompts the user for valid input until they provide it, using exception handling to manage invalid inputs.

# %%
while True:
    try:
        age = int(input("Enter your age: "))
        break
    except ValueError:
        print("Invalid input. Please enter a number.")
print("Your age is:", age)
# Out:
# Your age is: 30

# %% [markdown]
# ### Bonus Exercise 4: Log Errors to File
# Modify your error handling to log errors to a text file instead of printing them to the console.

# %%
try:
    num = int(input("Enter a number: "))
    result = 10 / num
except Exception as e:
    with open("error_log.txt", "a") as log:
        log.write(f"Error: {e}\n")
    print("An error occurred. It has been logged.")

# %% [markdown]
# ### Bonus Exercise 5: Retry Logic on Exception
# Implement retry logic for operations that could fail, allowing users to try again after encountering an error.

# %%
attempts = 0
while attempts < 3:
    try:
        x = int(input("Enter a number to divide 100 by: "))
        print("Result:", 100 / x)
        break
    except ZeroDivisionError:
        print("Cannot divide by zero.")
    except ValueError:
        print("Please enter a valid number.")
    attempts += 1
else:
    print("Too many failed attempts.")
# Out:
# Result: 50.0
