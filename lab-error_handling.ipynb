# %% [markdown]
# # LAB | Error Handling in Python
#
# ## Overview
# This exercise notebook will help you practice error handling in Python using exceptions. You will write programs that handle various types of exceptions to ensure your code runs smoothly and handles errors gracefully.

# %% [markdown]
# ### Exercise 1: Handle ZeroDivisionError
# Write a Python program to handle a `ZeroDivisionError` exception when dividing a number by zero.

# %%
# Your code here
try:
    # 10 ////// 0
    10 / 0
except:
    print("hello")
# Out:
# hello

# %% [markdown]
# ### Exercise 2: Raise ValueError for Invalid Input
# Write a Python program that prompts the user to input an integer and raises a `ValueError` exception if the input is not a valid integer.

# %%
# Your code here
user_input = input("Enter an integer: ")

if not user_input.lstrip("-").isdigit():
    raise ValueError(f"'{user_input}' is not a valid integer.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 5
#       2 user_input = input("Enter an integer: ")
#       4 if not user_input.lstrip("-").isdigit():
# ----> 5     raise ValueError(f"'{user_input}' is not a valid integer.")
#
# ValueError: '-6.7' is not a valid integer.

# %% [markdown]
# ### Exercise 3: Handle FileNotFoundError
# Write a Python program that opens a file and handles a `FileNotFoundError` exception if the file does not exist.

# %%
# Your code here
import os
import pandas as pd

try:
    # Trying to open a file that surely doesn't exist
    pd.read_csv("ghost_data.csv")

except FileNotFoundError:
    print(
        f"FileNotFoundError: could not find file. Current working dir is: {os.getcwd()}"
    )
# Out:
# FileNotFoundError: could not find file. Current working dir is: c:\Users\sol_v\OneDrive\Escritorio\IRON_AI\Exercises_and_Labs\Week_2\lab-py-error-handling

# %% [markdown]
# ### Exercise 4: Raise TypeError for Non-Numerical Input
# Write a Python program that prompts the user to input two numbers and raises a `TypeError` exception if the inputs are not numerical.

# %%
# Your code here
try:
    user_input1 = float(input("Enter an number 1: "))
    user_input2 = float(input("Enter an number 2: "))
except:
    raise TypeError("Input is not a number")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 3
#       2 try:
# ----> 3     user_input1 = float(input("Enter an number 1: "))
#       4     user_input2 = float(input("Enter an number 2: "))
#
# ValueError: could not convert string to float: 'ada'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 6
#       4     user_input2 = float(input("Enter an number 2: "))
#       5 except:
# ----> 6     raise TypeError("Input is not a number")
#
# TypeError: Input is not a number

# %% [markdown]
# ### Exercise 5: Handle PermissionError
# Write a Python program that opens a file and handles a `PermissionError` exception if there is a permission issue.

# %%
# Your code here
try: 
    file = open("whatever.txt")
    print(file.read())
except PermissionError:
    print("permission problem")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 3
#       1 # Your code here
#       2 try:
# ----> 3     file = open("whatever.txt")
#       4     print(file.read())
#       5 except PermissionError:
#
# File c:\Users\sol_v\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'whatever.txt'

# %% [markdown]
# ### Exercise 6: Handle IndexError in List Operations
# Write a Python program that executes an operation on a list and handles an `IndexError` exception if the index is out of range.

# %%
# Your code here
list = [1, 2, 3, 4, 5, 6, 7, 8, 9]
new_list = []

for i in range(20):
    try:
        new_list.append(list[i]**2)
    except IndexError: 
        print(f"The length is less than {i} ")
print(new_list)
# Out:
# The length is less than 9
# The length is less than 10
# The length is less than 11
# The length is less than 12
# The length is less than 13
# The length is less than 14
# The length is less than 15
# The length is less than 16
# The length is less than 17
# The length is less than 18
# The length is less than 19
# [1, 4, 9, 16, 25, 36, 49, 64, 81]

# %% [markdown]
# ### Exercise 7: Handle KeyboardInterrupt Exception
# Write a Python program that prompts the user to input a number and handles a `KeyboardInterrupt` exception if the user cancels the input.

# %%
# Your code here
try:
    num = float(input("Enter a number: "))
except KeyboardInterrupt:
    print("canceled")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 3
#       1 # Your code here
#       2 try:
# ----> 3     num = float(input("Enter a number: "))
#       4 except KeyboardInterrupt:
#       5     print("canceled")
#
# ValueError: could not convert string to float: ''

# %% [markdown]
# ### Exercise 8: Handle ArithmeticError
# Write a Python program that executes division and handles an `ArithmeticError` exception if there is an arithmetic error.

# %%
# Your code here
user_input1 = float(input("Enter an number 1: "))
user_input2 = float(input("Enter an number 2: "))
try:
   c = a/b
except ArithmeticError:
    print("Arithmetic error occured")
# Out:
# Arithmetic error

# %% [markdown]
# ### Exercise 9: Handle UnicodeDecodeError
# Write a Python program that opens a file and handles a `UnicodeDecodeError` exception if there is an encoding issue.

# %%
# Your code here
try: 
    file = open("whatever.txt")
    print(file.read())
except UnicodeDecodeError:
    print("there is an encoding issue.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[21], line 3
#       1 # Your code here
#       2 try:
# ----> 3     file = open("whatever.txt")
#       4     print(file.read())
#       5 except UnicodeDecodeError:
#
# File c:\Users\sol_v\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'whatever.txt'

# %% [markdown]
# ### Exercise 10: Handle AttributeError
# Write a Python program that executes an operation on an object and handles an `AttributeError` exception if the attribute does not exist.

# %%
# Your code here
try:
    num = 1
    print(num[10])
except AttributeError:
    print("The num is not a list")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 4
#       2 try:
#       3     num = 1
# ----> 4     print(num[10])
#       5 except AttributeError:
#       6     print("The num is not a list")
#
# TypeError: 'int' object is not subscriptable

# %% [markdown]
# ## Bonus Exercises
#
# ### Bonus Exercise 1: Handle Multiple Exceptions
# Write a Python program that demonstrates handling multiple exceptions in one block.

# %%
# Your code here
def safe_division(a, b):
    try:
        result = a / b
    except ZeroDivisionError:
        print("Error: You cannot divide by zero!")
        return None
    except TypeError:
        print("Error: Inputs must be numbers!")
        return None
    else:
        print("Successful division")
    finally:
        print("--- Operation Attempted ---")
print(safe_division(10, 2))
print(safe_division(10, 0))
print(safe_division(10, "0"))
# Out:
# Successful division
# --- Operation Attempted ---
# None
# Error: You cannot divide by zero!
# --- Operation Attempted ---
# None
# Error: Inputs must be numbers!
# --- Operation Attempted ---
# None

# %% [markdown]
# ### Bonus Exercise 2: Create Custom Exception
# Create a custom exception class and raise it in your code when certain conditions are met.

# %%
# Your code here
class MyCoolException(Exception):
    def __init__ (self, string):
        self.value = string
        
    def __str__ (self):
        return f"There was an error here: {self.value}"
    
def multiply_by_2 (x):
    if type(x) == int:
        return x*2
    else:
        raise MyCoolException("Input not valid")

multiply_by_2("asad")
# Out:
# ---------------------------------------------------------------------------
# MyCoolException                           Traceback (most recent call last)
# Cell In[31], line 15
#      12     else:
#      13         raise MyCoolException("Number not valid")
# ---> 15 multiply_by_2("asad")
#
# Cell In[31], line 13, in multiply_by_2(x)
#      11     return x*2
#      12 else:
# ---> 13     raise MyCoolException("Number not valid")
#
# MyCoolException: There was an error here: Number not valid

# %% [markdown]
# ### Bonus Exercise 3: Validate User Input with Exception Handling
# Write a program that repeatedly prompts the user for valid input until they provide it, using exception handling to manage invalid inputs.

# %%
# Your code here
while True:
    try:
        num = float(input("Enter a valid number: "))
        break
    except ValueError:
        print("Invalid input. Please try again.")
# Out:
# Invalid input. Please try again.
# Invalid input. Please try again.
# Invalid input. Please try again.

# %% [markdown]
# ### Bonus Exercise 4: Log Errors to File
# Modify your error handling to log errors to a text file instead of printing them to the console.

# %%
# Your code here

# %% [markdown]
# ### Bonus Exercise 5: Retry Logic on Exception
# Implement retry logic for operations that could fail, allowing users to try again after encountering an error.

# %%
# Your code here
